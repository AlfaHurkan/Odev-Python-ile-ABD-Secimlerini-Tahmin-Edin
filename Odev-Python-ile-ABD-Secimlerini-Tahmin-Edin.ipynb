# %% [markdown]
# ### https://thecleverprogrammer.com/2020/10/01/predict-us-elections-with-python/

# %%
#pip install nltk

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import scipy as sp
import nltk

# %%
from nltk.tokenize import sent_tokenize

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression #classification algoritmasi
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer

# %% [raw]
# # Bir NLP projesinde yapilmasi gerekenler
# 1- Hepsini kucuk harfe cevir
# 2- Rakamlari at
# 3- Satir sonlarini kaldir
# 4- Noktalama isaretlerini kaldir
# 5- Tekonize et
# 6- Ekleri kaldir kokleri bul
# 7- Stopwordsleri kaldir
# 8- N-gram iki kelime veya 3 veya N kelimeyi siyak sibak look for look up donmedi

# %%
df = pd.read_csv("Bidenall2.csv")
df.head()
# Out:
#            user                                               text
# 0   MarkHodder3    @JoeBiden And we’ll find out who won in 2026...
# 1    K87327961G  @JoeBiden Your Democratic Nazi Party cannot be...
# 2      OldlaceA                        @JoeBiden So did Lying Barr
# 3    penblogger  @JoeBiden It's clear you didnt compose this tw...
# 4  Aquarian0264         @JoeBiden I will vote in person thank you.

# %%
df2 = pd.read_csv("Trumpall2.csv")
df2.head()
# Out:
#               user                                               text
# 0      manny_rosen   @sanofi please tell us how many shares the Cr...
# 1        osi_abdul   https://t.co/atM98CpqF7  Like, comment, RT #P...
# 2          Patsyrw   Your AG Barr is as useless &amp; corrupt as y...
# 3  seyedebrahimi_m   Mr. Trump! Wake Up!  Most of the comments bel...
# 4    James09254677   After 4 years you think you would have figure...

# %%
df.shape
# Out:
# (2540, 2)

# %%
df2.shape
# Out:
# (2788, 2)

# %%
df['text']=df['text'].str.lower() #kucuk harfe cevir

# %%
df2['text']=df2['text'].str.lower() #kucuk harfe cevir

# %%
df['text']=df['text'].replace('[\d+]','') # rakamlari yoket

# %%
df2['text']=df2['text'].replace('[\d+]','') # rakamlari yoket

# %%
df['text']=df['text'].replace('[\w\s]','') # noktalama isaretlerini kaldir

# %%
df2['text']=df2['text'].replace('[\w\s]','') # noktalama isaretlerini kaldir

# %%
df['text']=df['text'].replace('[\n]','').replace('[\r]','') # yeni satir ve entera basilan yerleri kaldirdik

# %%
df2['text']=df2['text'].replace('[\n]','').replace('[\r]','') # yeni satir ve entera basilan yerleri kaldirdik

# %%
iyivekotu=df[(df['user']==5) | (df['user']==1)]

# %%
iyivekotu=df2[(df['user']==5) | (df2['user']==1)]

# %%
import ydata_profiling

# %%
df.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-12-28 10:15:14.447611&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df2.profile_report()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-12-28 10:15:30.869434&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
